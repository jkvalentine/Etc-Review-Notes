# %%
from bokeh.plotting import figure, output_notebook, show
import numpy as np
import pandas as pd

# %%
# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)

output_notebook()

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="55ab9f9a-6c97-4a77-b0ed-cbbe2c292ec4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="b754e225-67a7-427d-bf6e-ff2620564aa7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b754e225-67a7-427d-bf6e-ff2620564aa7").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b754e225-67a7-427d-bf6e-ff2620564aa7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b754e225-67a7-427d-bf6e-ff2620564aa7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a07d53c5-977a-4e1c-b609-281af82a9a9d":{"roots":{"references":[{"attributes":{"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"}},"id":"54398944-9229-4739-837d-90ffeecea0cd","type":"ResizeTool"},{"attributes":{"formatter":{"id":"a5c5bdfb-c9ec-4bf3-a5f3-8c161521ae19","type":"BasicTickFormatter"},"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"},"ticker":{"id":"77f325bb-75d2-403d-aa8d-b4e0ea4b5240","type":"BasicTicker"}},"id":"a37e5250-c9b4-4fde-aa0c-c5dfd6fa420d","type":"LinearAxis"},{"attributes":{},"id":"f0dd8226-b21f-4f5f-996c-b90af3c53250","type":"BasicTicker"},{"attributes":{"data_source":{"id":"5e4a3584-de5b-45b5-bc7f-30c796f260cd","type":"ColumnDataSource"},"glyph":{"id":"52d64fd0-732a-4dca-969a-397391d9cf35","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"d11b2bd1-aa70-4f5d-8633-e63217ba897d","type":"Circle"},"selection_glyph":null},"id":"7bdb0934-ece8-4113-8ba5-1c610258b2ce","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"}},"id":"7c184804-e4ff-4d07-ae76-d4614c9970e6","type":"PanTool"},{"attributes":{},"id":"7a91c39f-8dd5-49e2-a1c4-449fa49c2b10","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":100},"id":"f9b2b812-9aa8-4edf-8ae6-d96ce7fd7bbd","type":"Range1d"},{"attributes":{"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"}},"id":"087e3cfd-3d9a-4cbe-b5b3-454b3c8ba438","type":"ResetTool"},{"attributes":{},"id":"88ee9419-f209-41d5-be95-1414d6795d86","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"},"ticker":{"id":"77f325bb-75d2-403d-aa8d-b4e0ea4b5240","type":"BasicTicker"}},"id":"3e01bf36-ac08-408d-a75a-628390bae2fc","type":"Grid"},{"attributes":{},"id":"77f325bb-75d2-403d-aa8d-b4e0ea4b5240","type":"BasicTicker"},{"attributes":{"overlay":{"id":"fea4e9e6-7325-460e-9d15-d7dd69d03328","type":"BoxAnnotation"},"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"}},"id":"e1ac9d59-63c4-4f91-b5da-f6fc1e07ba4e","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":null},"id":"8d20abf1-3cf3-4f2c-9eb2-4d0ac6268acf","type":"Title"},{"attributes":{"callback":null,"overlay":{"id":"e7db1123-c148-4cef-9ce1-4a45cf107b14","type":"BoxAnnotation"},"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"},"renderers":[{"id":"7bdb0934-ece8-4113-8ba5-1c610258b2ce","type":"GlyphRenderer"}]},"id":"9f4f6dee-cdaf-4500-9594-ac97b3f5e3e7","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"c26b4a49-3097-48bd-a6a2-7c16f433660e","subtype":"Figure","type":"Plot"},"ticker":{"id":"f0dd8226-b21f-4f5f-996c-b90af3c53250","type":"BasicTicker"}},"id":"b9a34f71-e7e5-429d-9f3f-d35c5ddf5bd3","type":"Grid"},{"attributes":{"callback":null,"column_names":["radius","y","x","fill_color"],"data":{"fill_color":["#a0e396","#919a96","#c44f96","#7b5896","#90b996","#6f9a96","#54a996","#448a96","#e08896","#bb2896","#f95896","#af9896","#44df96","#d6d696","#e95096","#d12f96","#74d296","#864b96","#948296","#eec396","#776d96","#a1aa96","#5f8696","#69b496","#d5c396","#a02f96","#7dd596","#578c96","#cf2196","#772196","#5f3e96","#b63696","#a18496","#f55f96","#4fcd96","#9b7996","#a14396","#5b4d96","#c87596","#7dcd96","#c6c796","#7c2096","#4d4096","#4f1e96","#7fdc96","#90b796","#69ae96","#bea396","#f37296","#bce396","#6fd196","#ccc896","#8b2096","#a39396","#674696","#bd4d96","#39e396","#f5a096","#74d496","#886f96","#b5c496","#a14896","#c97896","#6f4396","#da2596","#a9b496","#40d996","#d47c96","#396296","#7e9996","#734896","#e98896","#be3596","#9c3796","#40e396","#ad2d96","#984a96","#c94b96","#4e7496","#acb596","#d45a96","#9f2396","#b17a96","#a51e96","#e32096","#4ad196","#91e096","#f64d96","#f56a96","#e7a696","#6ba896","#b02296","#a62d96","#933496","#514f96","#e97b96","#4c7096","#90c896","#804896","# ...
